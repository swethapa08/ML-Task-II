# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as s

# %%
a=pd.read_csv('Mall_Customers.csv')

# %%
a.head(10)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
a.shape
# Out:
# (200, 5)

# %%
d=a.iloc[:,[3,4]].values

# %%
d
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans
a= []
for i in range(1, 11):  
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 0)  
    kmeans.fit(d)  
    a.append(kmeans.inertia_)  
plt.plot(range(1, 11), wcss,  marker='o', c='cyan')  
plt.title('Elbow Graph')  
plt.xlabel('clusters')  
plt.ylabel('Inertia')  
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state= 0)  
predict_y= kmeans.fit_predict(d)

# %%
plt.scatter(d[predict_y == 0, 0], d[predict_y == 0, 1], s = 100, c ='Salmon', label = 'Cluster 1')  
plt.scatter(d[predict_y == 1, 0], d[predict_y == 1, 1], s = 100, c = 'pink', label = 'Cluster 2') 
plt.scatter(d[predict_y == 2, 0], d[predict_y == 2, 1], s = 100, c = 'PaleGreen', label = 'Cluster 3')   
plt.scatter(d[predict_y == 3, 0], d[predict_y == 3, 1], s = 100, c = 'violet', label = 'Cluster 4')  
plt.scatter(d[predict_y == 4, 0], d[predict_y == 4, 1], s = 100, c = 'cyan', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='^', s = 300, c = 'DarkBlue', label = 'Centroid')    
plt.title('CLUSTERS')  
plt.xlabel('Annual Income')  
plt.ylabel('Spending Score')  
plt.legend()  
plt.show()
